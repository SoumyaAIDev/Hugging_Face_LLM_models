# %% [markdown]
# <a href="https://colab.research.google.com/github/SoumyaAIDev/Hugging_Face_LLM_models/blob/main/solidity_LLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install accelerate peft==0.13.2 bitsandbytes transformers trl==0.12.1

# %%
# !pip install trl

# %%
# !pip install bitsandbytes

# %%
# !pip install -U bitsandbytes

# %%
import torch
from trl import SFTTrainer
from peft import LoraConfig
from datasets import load_dataset
from transformers import (AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, TrainingArguments, pipeline)

# %%
# !pip install bitsandbytes==0.41.3
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 7.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: bitsandbytes
#     Found existing installation: bitsandbytes 0.44.1
#     Uninstalling bitsandbytes-0.44.1:
#       Successfully uninstalled bitsandbytes-0.44.1
# ...

# %%
   llama_model =AutoModelForCausalLM.from_pretrained(pretrained_model_name_or_path = "AlfredPros/CodeLlama-7b-Instruct-Solidity",
                                           quantization_config = BitsAndBytesConfig(load_in_4bit = True,
                                                                                    bnb_4bit_compute_dtype = getattr(torch,"float16"),
                                                                                    bnb_4bit_quant_type ="nf4" )       )
llama_model.config.use_cache =False
llama_model.config.pretraining_tp = 1
# Out:
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# pytorch_model.bin.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# ...
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]

# %% [markdown]
# <a href="https://colab.research.google.com/github/SoumyaAIDev/Hugging_Face_LLM_models/blob/main/hululuzhu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# !pip install transformers
# !pip install datasets

# %%
from datasets import load_dataset
dataset = load_dataset("hululuzhu/silly-emoji-qa")
print(dataset["train"].to_pandas().head(10))
# Out:
# README.md:   0%|          | 0.00/436 [00:00<?, ?B/s]
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# train.csv:   0%|          | 0.00/16.0k [00:00<?, ?B/s]
# test.csv:   0%|          | 0.00/510 [00:00<?, ?B/s]
# ...
# Generating test split:   0%|          | 0/10 [00:00<?, ? examples/s]
#                                             Question  Answer
# 0               Why do we have different time zones?     🌏⏰🔄
# 1  How do spiders make webs that don't stick to t...  🕷️🕸️🚫🔗
# 2      Why do we need to wear seat belts in the car?   🚗💥👧‍🚀
# 3          How do trees drink water from the ground?     🌳💧👄
# 4               Why do some animals have long beaks?     🐦👃🥖
# 5                 How do submarines stay underwater?   ⚓️⬇️🌊
# 6               Why do we have different eye colors?    👁️🌈🧬
# 7                   How do chameleons change colors?     🦎🎨🎭
# ...

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration
tokenizer = T5Tokenizer.from_pretrained("t5-small")
model = T5ForConditionalGeneration.from_pretrained("t5-small")

data = {
    "question": ["Why do we have different time zones? ",
1  "How do spiders make webs that don't stick to t... ",
2     " Why do we need to wear seat belts in the car? ",
3          "How do trees drink water from the ground? ",
4               "Why do some animals have long beaks?     🐦👃🥖
5                 How do submarines stay underwater?  "]

}

# %% [markdown]
# <a href="https://colab.research.google.com/github/SoumyaAIDev/Hugging_Face_LLM_models/blob/main/solidity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install transformers datasets torch

# %%
[
    {"input": "Create a Solidity function to transfer tokens", "output": "function transfer(address to, uint256 amount) public { ... }"},
    {"input": "A payable function to receive Ether", "output": "function receiveEther() public payable { ... }"}
]
# Out:
# [{'input': 'Create a Solidity function to transfer tokens',
#   'output': 'function transfer(address to, uint256 amount) public { ... }'},
#  {'input': 'A payable function to receive Ether',
#   'output': 'function receiveEther() public payable { ... }'}]

# %%
from transformers import T5Tokenizer

# Initialize tokenizer
tokenizer = T5Tokenizer.from_pretrained("t5-small")

# Example preprocessing
def preprocess_function(example):
    input_text = example['input']
    target_text = example['output']
    model_inputs = tokenizer(input_text, max_length=512, truncation=True, padding="max_length")
    labels = tokenizer(target_text, max_length=512, truncation=True, padding="max_length")
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
from datasets import load_dataset

# Load dataset
data = load_dataset('ASSERT-KTH/DISL','decomposed', split='train')

# Apply preprocessing
processed_data = data.map(preprocess_function, batched=True)
# Out:
# ...
# Map:   0%|          | 0/514506 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-1c741b7a9ccb> in <cell line: 7>()
#       5
#       6 # Apply preprocessing
# ----> 7 processed_data = data.map(preprocess_function, batched=True)
#
# /usr/local/lib/python3.10/dist-packages/datasets/arrow_dataset.py in wrapper(*args, **kwargs)
#     558         }
#     559         # apply actual function
# --> 560         out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     561         datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     562         # re-apply format to the output
#
# ...
